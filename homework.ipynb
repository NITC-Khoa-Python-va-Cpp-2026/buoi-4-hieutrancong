# %%
file = open("input.txt", 'r', encoding = "utf-8")

cnt = 0
while(file.readline() != ""):
    cnt += 1  
print(cnt)

file.close()
# Out:
# 10

# %%
file1 = open("input.txt", 'r', encoding = "utf-8")
file2 = open("copy.txt", 'w', encoding = "utf-8")

data = file1.read()
file2.write(data)

file1.close()
file2.close()

# %%
file1 = open("copy.txt", 'r', encoding = "utf-8")
file2 = open("output.txt", 'w', encoding = "utf-8")

# copy 5 dòng đầu
lst = file1.readlines()

# Cách 1:
'''
for i in range(5):
    file2.write(lst[i])
'''

# Cách 2: 
file2.writelines(lst[:5]) 

file2.write("Họ và tên: Trần Công Hiếu\n")

file1.close()
file2.close()
